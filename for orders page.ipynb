# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

# Initialize the OneHotEncoder with handle_unknown='ignore'
encoder = OneHotEncoder(handle_unknown='ignore')

# Training data
# Define the features (input) and labels (output) for training the decision tree
# Modify the features and labels according to your specific orders page implementation
# For example, if your orders page has fields like food item, quantity, delivery address, payment method, etc., define them as features
# and if you have expected outcomes like "Order placed", "Out of stock", "Payment failed", etc. as labels, define them accordingly

# Features (input)
X_train = [
    ['Pizza', 2, '1234 Elm St', 'Credit Card'],  # Sample data for a valid order
    ['Burger', 1, '5678 Oak St', 'Debit Card'],  # Sample data for a valid order
    ['Salad', 3, '7890 Main St', 'Cash on Delivery'],  # Sample data for a valid order
    ['Sushi', 0, '5678 Elm St', 'Credit Card'],  # Sample data for an invalid order (quantity 0)
    ['Pasta', -1, '1234 Oak St', 'Debit Card'],  # Sample data for an invalid order (negative quantity)
    ['Biryani', 4, '7890 Elm St', 'Cash on Delivery'],  # Sample data for an invalid order (quantity > 3)
    ['Pizza', 1, '', 'Credit Card'],  # Sample data for an invalid order (empty delivery address)
    ['Burger', 2, '5678 Main St', ''],  # Sample data for an invalid order (empty payment method)
    ['Salad', 3, '1234 Elm St', 'Credit Card'],  # Sample data for a valid order
    ['Sushi', 1, '5678 Oak St', 'Debit Card'],  # Sample data for a valid order
]

# Labels (output)
y_train = [
    'Order placed successfully',
    'Order placed successfully',
    'Order placed successfully',
    'Invalid quantity',
    'Invalid quantity',
    'Invalid quantity',
    'Invalid delivery address',
    'Invalid payment method',
    'Order placed successfully',
    'Order placed successfully',
]

# Perform one-hot encoding on the input features
encoder = OneHotEncoder()
X_train_encoded = encoder.fit_transform(X_train).toarray()

# Initialize and train the decision tree
clf = DecisionTreeClassifier()
clf.fit(X_train_encoded, y_train)

# Testing data
# Define the features (input) for testing the decision tree
# Modify the features according to your specific orders page implementation
# For example, if your orders page has fields like food item, quantity, delivery address, payment method, etc., define them as features for testing

# Features (input)
X_test = [
   ['Pizza', 2, '1234 Elm St', 'Credit Card'],  # Sample data for a valid order
    ['Burger', 1, '5678 Oak St', 'Debit Card'],  # Sample data for a valid order
    ['Salad', 3, '7890 Main St', 'Cash on Delivery'],  # Sample data for a valid order
    ['Sushi', 0, '5678 Elm St', 'Credit Card'],  # Sample data for an invalid order (quantity 0)
    ['Pasta', -1, '1234 Oak St', 'Debit Card'],  # Sample data for an invalid order (negative quantity)
    ['Biryani', 4, '7890 Elm St', 'Cash on Delivery'],  # Sample data for an invalid order (quantity > 3)
    ['Pizza', 1, '', 'Credit Card'],  # Sample data for an invalid order (empty delivery address)
    ['Burger', 2, '5678 Main St', ''],  # Sample data for an invalid order (empty payment method)
    ['Salad', 3, '1234 Elm St', 'Credit Card'],  # Sample data for a valid order
    ['Sushi', 1, '5678 Oak St', 'Debit Card'],  # Sample data for a valid order
]

# Perform one-hot encoding on the input features
X_test_encoded = encoder.transform(X_test).toarray()

# Predict the outcomes using the trained decision tree
y_pred = clf.predict(X_test_encoded)

# Check the predicted outcomes against the expected outcomes
# Modify the expected outcomes according to the expected results for each sample data
# For example, if you expect the order to be successfully placed, use 'Order placed' as the expected outcome
# If you expect an error message like 'Out of stock', 'Payment failed', etc., use the appropriate error message as the expected outcome

# Expected outcomes
expected_outcomes = [
   'Order placed successfully',
    'Order placed successfully',
    'Order placed successfully',
    'Invalid quantity',
    'Invalid quantity',
    'Invalid quantity',
    'Invalid delivery address',
    'Invalid payment method',
    'Order placed successfully',
    'Order placed successfully',
]

# Compare the predicted outcomes with the expected outcomes
for i in range(len(X_test)):
    print(f"Test case {i+1}:")
    print(f"Input data: {X_test[i]}")
    print(f"Predicted outcome: {y_pred[i]}")
    print(f"Expected outcome: {expected_outcomes[i]}")
    print("Pass" if y_pred[i] == expected_outcomes[i] 
          else "Fail")
    print("---")
# Out:
# Test case 1:
# Input data: ['Pizza', 2, '1234 Elm St', 'Credit Card']
# Predicted outcome: Order placed successfully
# Expected outcome: Order placed successfully
# Pass
# ---
# Test case 2:
# Input data: ['Burger', 1, '5678 Oak St', 'Debit Card']
# Predicted outcome: Order placed successfully
# Expected outcome: Order placed successfully
# Pass
# ---
# Test case 3:
# Input data: ['Salad', 3, '7890 Main St', 'Cash on Delivery']
# Predicted outcome: Order placed successfully
# Expected outcome: Order placed successfully
# Pass
# ---
# Test case 4:
# Input data: ['Sushi', 0, '5678 Elm St', 'Credit Card']
# Predicted outcome: Invalid quantity
# Expected outcome: Invalid quantity
# Pass
# ---
# Test case 5:
# Input data: ['Pasta', -1, '1234 Oak St', 'Debit Card']
# Predicted outcome: Invalid quantity
# Expected outcome: Invalid quantity
# Pass
# ---
# Test case 6:
# Input data: ['Biryani', 4, '7890 Elm St', 'Cash on Delivery']
# Predicted outcome: Invalid quantity
# ...

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
import numpy as np

# Initialize the OneHotEncoder with handle_unknown='ignore'
encoder = OneHotEncoder(handle_unknown='ignore')

# Define the features (input) and labels (output) for training the decision tree
# Modify the features and labels according to your specific orders page implementation
# For example, if your orders page has fields like food item, quantity, delivery address, payment method, etc.,
# define them as features and if you have expected outcomes like "Order placed successfully", "Invalid quantity", etc.,
# as labels, define them accordingly

# Features (input)
X_train = [
    ['Pizza', 2, '1234 Elm St', 'Credit Card'],  # Sample data for a valid order
    ['Burger', 1, '5678 Oak St', 'Debit Card'],  # Sample data for a valid order
    ['Salad', 3, '7890 Main St', 'Cash on Delivery'],  # Sample data for a valid order
    ['Sushi', 0, '5678 Elm St', 'Credit Card'],  # Sample data for an invalid order (quantity 0)
    ['Pasta', -1, '1234 Oak St', 'Debit Card'],  # Sample data for an invalid order (negative quantity)
    ['Biryani', 4, '7890 Elm St', 'Cash on Delivery'],  # Sample data for an invalid order (quantity > 3)
    ['Pizza', 1, '', 'Credit Card'],  # Sample data for an invalid order (empty delivery address)
    ['Burger', 2, '5678 Main St', ''],  # Sample data for an invalid order (empty payment method)
    ['Salad', 3, '1234 Elm St', 'Credit Card'],  # Sample data for a valid order
    ['Sushi', 1, '5678 Oak St', 'Debit Card'],  # Sample data for a valid order
]

# Labels (output)
y_train = [
    'Order placed successfully',
    'Order placed successfully',
    'Order placed successfully',
    'Invalid quantity',
    'Invalid quantity',
    'Invalid quantity',
    'Invalid delivery address',
    'Invalid payment method',
    'Order placed successfully',
    'Order placed successfully',
]

# Perform one-hot encoding on the input features
encoder = OneHotEncoder()
X_train_encoded = encoder.fit_transform(X_train).toarray()

# Initialize and train the decision tree
clf = DecisionTreeClassifier()
clf.fit(X_train_encoded, y_train)

# Define the features (input) for testing the decision tree
# Modify the features according to your specific orders page implementation
# For example, if your orders page has fields like food item, quantity, delivery address, payment method, etc.,
# define them as features for testing

# Features (input)
X_test = [['Pizza', 2, '1234 Elm St', 'Credit Card'],  # Sample data for a valid order
    ['Burger', 1, '5678 Oak St', 'Debit Card'],  # Sample data for a valid order
    ['Salad', 3, '7890 Main St', 'Cash on Delivery'],  # Sample data for a valid order
    ['Sushi', 0, '5678 Elm St', 'Credit Card'],  # Sample data for an invalid order (quantity 0)
    ['Pasta', -1, '1234 Oak St', 'Debit Card'],  # Sample data for an invalid order (negative quantity)
    ['Biryani', 4, '7890 Elm St', 'Cash on Delivery'],  # Sample data for an invalid order (quantity > 3)
    ['Pizza', 1, '', 'Credit Card'],  # Sample data for an invalid order (empty delivery address)
    ['Burger', 2, '5678 Main St', ''],  # Sample data for an invalid order (empty payment method)
    ['Salad', 3, '1234 Elm St', 'Credit Card'],  # Sample data for a valid order
    ['Sushi', 1, '5678 Oak St', 'Debit Card'],  # Sample data for a valid order
]

# Perform one-hot encoding on the input features
X_test_encoded = encoder.transform(X_test).toarray()

# Make predictions using the trained decision tree
y_pred = clf.predict(X_test_encoded)

# Print the predicted labels for the test data
print("Predicted Labels:")
for i in range(len(X_test)):
    print("Order Details: {}, Predicted Label: {}".format(X_test[i], y_pred[i]))
# Out:
# Predicted Labels:
# Order Details: ['Pizza', 2, '1234 Elm St', 'Credit Card'], Predicted Label: Order placed successfully
# Order Details: ['Burger', 1, '5678 Oak St', 'Debit Card'], Predicted Label: Order placed successfully
# Order Details: ['Salad', 3, '7890 Main St', 'Cash on Delivery'], Predicted Label: Order placed successfully
# Order Details: ['Sushi', 0, '5678 Elm St', 'Credit Card'], Predicted Label: Invalid quantity
# Order Details: ['Pasta', -1, '1234 Oak St', 'Debit Card'], Predicted Label: Invalid quantity
# Order Details: ['Biryani', 4, '7890 Elm St', 'Cash on Delivery'], Predicted Label: Invalid quantity
# Order Details: ['Pizza', 1, '', 'Credit Card'], Predicted Label: Invalid delivery address
# Order Details: ['Burger', 2, '5678 Main St', ''], Predicted Label: Invalid payment method
# Order Details: ['Salad', 3, '1234 Elm St', 'Credit Card'], Predicted Label: Order placed successfully
# ...

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
import numpy as np

# Initialize the OneHotEncoder with handle_unknown='ignore'
encoder = OneHotEncoder(handle_unknown='ignore')

# Define the features (input) and labels (output) for training the decision tree
# Modify the features and labels according to your specific orders page implementation
# For example, if your orders page has fields like food item, quantity, delivery address, payment method, etc.,
# define them as features and if you have expected outcomes like "Order placed successfully", "Invalid quantity", etc.,
# as labels, define them accordingly

# Features (input)
X_train = [
    ['Pizza', 2, '1234 Elm St', 'Credit Card'],  # Sample data for a valid order
    ['Burger', 1, '5678 Oak St', 'Debit Card'],  # Sample data for a valid order
    ['Salad', 3, '7890 Main St', 'Cash on Delivery'],  # Sample data for a valid order
    ['Sushi', 0, '5678 Elm St', 'Credit Card'],  # Sample data for an invalid order (quantity 0)
    ['Pasta', -1, '1234 Oak St', 'Debit Card'],  # Sample data for an invalid order (negative quantity)
    ['Biryani', 4, '7890 Elm St', 'Cash on Delivery'],  # Sample data for an invalid order (quantity > 3)
    ['Pizza', 1, '', 'Credit Card'],  # Sample data for an invalid order (empty delivery address)
    ['Burger', 2, '5678 Main St', ''],  # Sample data for an invalid order (empty payment method)
    ['Salad', 3, '1234 Elm St', 'Credit Card'],  # Sample data for a valid order
    ['Sushi', 1, '5678 Oak St', 'Debit Card'],  # Sample data for a valid order
]

# Labels (output)
y_train = [
    'Order placed successfully',
    'Order placed successfully',
    'Order placed successfully',
    'Invalid quantity',
    'Invalid quantity',
    'Invalid quantity',
    'Invalid delivery address',
    'Invalid payment method',
    'Order placed successfully',
    'Order placed successfully',
]

# Perform one-hot encoding on the input features
encoder = OneHotEncoder()
X_train_encoded = encoder.fit_transform(X_train).toarray()

# Initialize and train the decision tree
clf = DecisionTreeClassifier()
clf.fit(X_train_encoded, y_train)

# Define the features (input) for testing the decision tree
# Modify the features according to your specific orders page implementation
# For example, if your orders page has fields like food item, quantity, delivery address, payment method, etc.,
# define them as features for testing
# Features (input) for testing
# Features (input) for testing
X_test = [
    ['Pizza', 2, '1234 Elm St', 'Credit Card'],  # Sample data for a valid order
    ['Burger', 1, '5678 Oak St', 'Debit Card'],  # Sample data for a valid order
    ['Salad', 3, '7890 Main St', 'Cash on Delivery'],  # Sample data for a valid order
    ['Sushi', 0, '5678 Elm St', 'Credit Card'],  # Sample data for an invalid order (quantity 0)
    ['Pasta', -1, '1234 Oak St', 'Debit Card'],  # Sample data for an invalid order (negative quantity)
    ['Biryani', 4, '7890 Elm St', 'Cash on Delivery'],  # Sample data for an invalid order (quantity > 3)
    ['Pizza', 1, '', 'Credit Card'],  # Sample data for an invalid order (empty delivery address)
    ['Burger', 2, '5678 Main St', ''],  # Sample data for an invalid order (empty payment method)
    ['Salad', 3, '1234 Elm St', 'Credit Card'],  # Sample data for a valid order
    ['Sushi', 1, '5678 Oak St', 'Debit Card'],  # Sample data for a valid order
]

# Expected labels for the test cases (1: Pass, 0: Fail)
y_test_expected = [1, 1, 1, 0, 0, 0, 0, 0, 1, 1]

# Perform one-hot encoding on the input features
X_test_encoded = encoder.transform(X_test).toarray()

# Make predictions using the trained decision tree
y_pred = clf.predict(X_test_encoded)

# Print the predicted labels for the test data and whether the test case passed or failed
print("Test Results:")
for i in range(len(X_test)):
    if y_pred[i] == y_test_expected[i]:
        result = "Pass"
    else:
        result = "Fail"
    print("Order Details: {}\nExpected Label: {}\nPredicted Label: {}\nResult: {}\n".format(X_test[i], y_test_expected[i], y_pred[i], result))
from sklearn.metrics import accuracy_score

# Assuming you have trained the decision tree model and obtained predictions in y_pred

# Convert the expected labels to binary (0 for fail, 1 for pass)
y_test_expected_binary = [1 if label == 'Order placed successfully' else 0 for label in y_test_expected]

# Convert the predicted labels to binary (0 for fail, 1 for pass)
y_pred_binary = [1 if label == 'Order placed successfully' else 0 for label in y_pred]

# Calculate accuracy
accuracy = accuracy_score(y_test_expected_binary, y_pred_binary)

print("Accuracy: {:.2f}%".format(accuracy * 100))
# Out:
# Test Results:
# Order Details: ['Pizza', 2, '1234 Elm St', 'Credit Card']
# Expected Label: 1
# Predicted Label: Order placed successfully
# Result: Fail
#
# Order Details: ['Burger', 1, '5678 Oak St', 'Debit Card']
# Expected Label: 1
# Predicted Label: Order placed successfully
# Result: Fail
#
# Order Details: ['Salad', 3, '7890 Main St', 'Cash on Delivery']
# Expected Label: 1
# Predicted Label: Order placed successfully
# Result: Fail
#
# Order Details: ['Sushi', 0, '5678 Elm St', 'Credit Card']
# Expected Label: 0
# Predicted Label: Invalid quantity
# Result: Fail
#
# Order Details: ['Pasta', -1, '1234 Oak St', 'Debit Card']
# Expected Label: 0
# Predicted Label: Invalid quantity
# Result: Fail
#
# Order Details: ['Biryani', 4, '7890 Elm St', 'Cash on Delivery']
# Expected Label: 0
# Predicted Label: Invalid quantity
# Result: Fail
#
# Order Details: ['Pizza', 1, '', 'Credit Card']
# Expected Label: 0
# Predicted Label: Invalid delivery address
# Result: Fail
#
# ...
