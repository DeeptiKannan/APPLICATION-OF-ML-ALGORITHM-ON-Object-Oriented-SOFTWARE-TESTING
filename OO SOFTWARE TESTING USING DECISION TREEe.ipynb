# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
# Initialize the OneHotEncoder with handle_unknown='ignore'
encoder = OneHotEncoder(handle_unknown='ignore')


# Training data
# Define the features (input) and labels (output) for training the decision tree
# Modify the features and labels according to your specific registration page implementation
# For example, if your registration page has fields like username, email, password, etc., define them as features
# and if you have expected outcomes like "Registration successful" or "Username already taken" as labels, define them accordingly

# Features (input)
X_train = [
    ['deepti', 'deeptikannan@gmail.com', 'deeps'],  # Sample data for a valid registration
    ['subhi', 'subbu@gmail.com', 'subbu'],  # Sample data for a valid registration
    ['sarvesh', 'sarvu@gmail.com', 'sarv'],
    ['john', 'johnsmith@gmail.com', 'password123'],
    ['sara', 'sara28@yahoo.com', 'myp@ssw0rd'],
    ['Aditi', 'aditi.gupta@hotmail.com', 'myp@ssw0rd'],
    ['Amit', 'amit.singh@yahoo.com', 'welcome123'],
    ['Anaya', 'anaya.joshi@gmail.com', 'ilovecoding'],
    ['Aryan', 'aryan.verma@hotmail.com', 'myp@ssw0rd'],
    ['Aisha', 'aisha.khan@gmail.com', 'myp@ssw0rd'],
    ['Arjun', 'arjun.sharma@yahoo.com', '123456789'],
    ['Avani', 'avani.gupta@gmail.com', 'myp@ssw0rd'],
    ['Ayush', 'ayush.jain@hotmail.com', 'ilovecoding'],
    ['Bhavya', 'bhavya.singh@gmail.com', 'myp@ssw0rd'],
    ['Devansh', 'devansh.kumar@yahoo.com', 'password123'],
    ['Eesha', 'eesha.sharma@gmail.com', 'myp@ssw0rd'],
    ['Gauri', 'gauri.gupta@hotmail.com', 'welcome123'],
    ['Harshita', 'harshita.joshi@gmail.com', 'myp@ssw0rd'],
    ['Ishaan', 'ishaan.kumar@yahoo.com', 'ilovecoding'],
    ['Kavya', 'kavya.verma@gmail.com', 'myp@ssw0rd'],
    ['Prisha', 'prisha.sharma@hotmail.com', 'myp@ssw0rd'],
]

# Labels (output)
y_train = [
    'Registration successful',
    'Registration successful',
    'Username already taken',  # Expected outcome for an unsuccessful registration (username already taken)
    'Email already registered',  # Expected outcome for an unsuccessful registration (email already registered)
    'Weak password',  # Expected outcome for an unsuccessful registration (weak password)
    'Unsuccessful registration',
    'Registration successful',
    'Unsuccessful registration',
    'Unsuccessful registration',
    'Unsuccessful registration',
    'Unsuccessful registration',
    'Registration successful',
    'Unsuccessful registration',
    'Registration successful',
    'Registration successful',
    'Unsuccessful registration',
    'Registration successful',
    'Registration successful',
    'Unsuccessful registration',
    'Registration successful',
    'Registration successful',  
]

# Perform one-hot encoding on the input features
encoder = OneHotEncoder()
X_train_encoded = encoder.fit_transform(X_train).toarray()

# Initialize and train the decision tree
clf = DecisionTreeClassifier()
clf.fit(X_train_encoded, y_train)

# Testing data
# Define the features (input) for testing the decision tree
# Modify the features according to your specific registration page implementation
# For example, if your registration page has fields like username, email, password, etc., define them as features for testing

# Features (input)
X_test = [
    ['deepti', 'deeptikannan@gmail.com', 'deeps'],  # Sample data for a valid registration
    ['subhi', 'subbu@gmail.com', 'subbu'],  # Sample data for a valid registration
    ['sarvesh', 'sarvu@gmail.com', 'sarv'],
    ['john', 'johnsmith@gmail.com', 'password123'],
    ['sara', 'sara28@yahoo.com', 'myp@ssw0rd'],
    ['Aditi', 'aditi.gupta@hotmail.com', 'myp@ssw0rd'],
    ['Amit', 'amit.singh@yahoo.com', 'welcome123'],
    ['Anaya', 'anaya.joshi@gmail.com', 'ilovecoding'],
    ['Aryan', 'aryan.verma@hotmail.com', 'myp@ssw0rd'],
    ['Aisha', 'aisha.khan@gmail.com', 'myp@ssw0rd'],
    ['Arjun', 'arjun.sharma@yahoo.com', '123456789'],
    ['Avani', 'avani.gupta@gmail.com', 'myp@ssw0rd'],
    ['Ayush', 'ayush.jain@hotmail.com', 'ilovecoding'],
    ['Bhavya', 'bhavya.singh@gmail.com', 'myp@ssw0rd'],
    ['Devansh', 'devansh.kumar@yahoo.com', 'password123'],
    ['Eesha', 'eesha.sharma@gmail.com', 'myp@ssw0rd'],
    ['Gauri', 'gauri.gupta@hotmail.com', 'welcome123'],
    ['Harshita', 'harshita.joshi@gmail.com', 'myp@ssw0rd'],
    ['Ishaan', 'ishaan.kumar@yahoo.com', 'ilovecoding'],
    ['Kavya', 'kavya.verma@gmail.com', 'myp@ssw0rd'],
    ['Prisha', 'prisha.sharma@hotmail.com', 'myp@ssw0rd'],
   
]

# Perform one-hot encoding on the input features
X_test_encoded = encoder.transform(X_test).toarray()

# Predict the outcomes using the trained decision tree
y_pred = clf.predict(X_test_encoded)

# Check the predicted outcomes against the expected outcomes
# Modify the expected outcomes according to the expected results for each sample data
# For example, if you expect the registration to be successful, use 'Registration successful' as the expected outcome
# If you expect an error message like 'Username already taken', use the appropriate error message as the expected outcome

# Expected outcomes
expected_outcomes = [
    'Registration successful',
    'Registration successful',
    'Username already taken',  # Expected outcome for an unsuccessful registration (username already taken)
    'Email already registered',  # Expected outcome for an unsuccessful registration (email already registered)
    'Weak password',  # Expected outcome for an unsuccessful registration (weak password)
    'Unsuccessful registration',
    'Registration successful',
    'Unsuccessful registration',
    'Unsuccessful registration',
    'Unsuccessful registration',
    'Unsuccessful registration',
    'Registration successful',
    'Unsuccessful registration',
    'Registration successful',
    'Registration successful',
    'Unsuccessful registration',
    'Registration successful',
    'Registration successful',
    'Unsuccessful registration',
    'Registration successful',
    'Registration successful',  
]

# Compare the predicted outcomes with the expected outcomes
for i in range(len(X_test)):
    print(f"Test case {i+1}:")
    print(f"Input data: {X_test[i]}")
    print(f"Predicted outcome: {y_pred[i]}")
    print(f"Expected outcome: {expected_outcomes[i]}")
    print("Pass" if y_pred[i] == expected_outcomes[i] 
          else "Fail")
    print("---")
# Out:
# Test case 1:
# Input data: ['deepti', 'deeptikannan@gmail.com', 'deeps']
# Predicted outcome: Registration successful
# Expected outcome: Registration successful
# Pass
# ---
# Test case 2:
# Input data: ['subhi', 'subbu@gmail.com', 'subbu']
# Predicted outcome: Registration successful
# Expected outcome: Registration successful
# Pass
# ---
# Test case 3:
# Input data: ['sarvesh', 'sarvu@gmail.com', 'sarv']
# Predicted outcome: Username already taken
# Expected outcome: Username already taken
# Pass
# ---
# Test case 4:
# Input data: ['john', 'johnsmith@gmail.com', 'password123']
# Predicted outcome: Email already registered
# Expected outcome: Email already registered
# Pass
# ---
# Test case 5:
# Input data: ['sara', 'sara28@yahoo.com', 'myp@ssw0rd']
# Predicted outcome: Weak password
# Expected outcome: Weak password
# Pass
# ---
# Test case 6:
# Input data: ['Aditi', 'aditi.gupta@hotmail.com', 'myp@ssw0rd']
# Predicted outcome: Unsuccessful registration
# ...

# %%
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
# Initialize the OneHotEncoder with handle_unknown='ignore'

encoder = OneHotEncoder(handle_unknown='ignore')


# Training data
# Define the features (input) and labels (output) for training the decision tree
# Modify the features and labels according to your specific registration page implementation
# For example, if your registration page has fields like username, email, password, etc., define them as features
# and if you have expected outcomes like "Registration successful" or "Username already taken" as labels, define them accordingly

# Features (input)
X_train = [
    ['deepti', 'deeptikannan@gmail.com', 'deeps'],  # Sample data for a valid registration
    ['subhi', 'subbu@gmail.com', 'subbu'],  # Sample data for a valid registration
    ['sarvesh', 'sarvu@gmail.com', 'sarv'],
    ['john', 'johnsmith@gmail.com', 'password123'],
    ['sara', 'sara28@yahoo.com', 'myp@ssw0rd'],
    ['Aditi', 'aditi.gupta@hotmail.com', 'myp@ssw0rd'],
    ['Amit', 'amit.singh@yahoo.com', 'welcome123'],
    ['Anaya', 'anaya.joshi@gmail.com', 'ilovecoding'],
    ['Aryan', 'aryan.verma@hotmail.com', 'myp@ssw0rd'],
    ['Aisha', 'aisha.khan@gmail.com', 'myp@ssw0rd'],
    ['Arjun', 'arjun.sharma@yahoo.com', '123456789'],
    ['Avani', 'avani.gupta@gmail.com', 'myp@ssw0rd'],
    ['Ayush', 'ayush.jain@hotmail.com', 'ilovecoding'],
    ['Bhavya', 'bhavya.singh@gmail.com', 'myp@ssw0rd'],
    ['Devansh', 'devansh.kumar@yahoo.com', 'password123'],
    ['Eesha', 'eesha.sharma@gmail.com', 'myp@ssw0rd'],
    ['Gauri', 'gauri.gupta@hotmail.com', 'welcome123'],
    ['Harshita', 'harshita.joshi@gmail.com', 'myp@ssw0rd'],
    ['Ishaan', 'ishaan.kumar@yahoo.com', 'ilovecoding'],
    ['Kavya', 'kavya.verma@gmail.com', 'myp@ssw0rd'],
    ['Prisha', 'prisha.sharma@hotmail.com', 'myp@ssw0rd'],
]

# Labels (output)
y_train = [
    'Registration successful',
    'Registration successful',
    'Username already taken',  # Expected outcome for an unsuccessful registration (username already taken)
    'Email already registered',  # Expected outcome for an unsuccessful registration (email already registered)
    'Weak password',  # Expected outcome for an unsuccessful registration (weak password)
    'Unsuccessful registration',
    'Registration successful',
    'Unsuccessful registration',
    'Unsuccessful registration',
    'Unsuccessful registration',
    'Unsuccessful registration',
    'Registration successful',
    'Unsuccessful registration',
    'Registration successful',
    'Registration successful',
    'Unsuccessful registration',
    'Registration successful',
    'Registration successful',
    'Unsuccessful registration',
    'Registration successful',
    'Registration successful',  
]

# Perform one-hot encoding on the input features
encoder = OneHotEncoder()
X_train_encoded = encoder.fit_transform(X_train).toarray()

# Initialize and train the decision tree
clf = DecisionTreeClassifier()
clf.fit(X_train_encoded, y_train)

# Testing data
# Define the features (input) for testing the decision tree
# Modify the features according to your specific registration page implementation
# For example, if your registration page has fields like username, email, password, etc., define them as features for testing

# Features (input)
X_test = [
    ['deepti', 'deeptikannan@gmail.com', 'deeps'],  # Sample data for a valid registration
    ['subhi', 'subbu@gmail.com', 'subbu'],  # Sample data for a valid registration
    ['sarvesh', 'sarvu@gmail.com', 'darv'],
    ['john', 'johnsmith@gmail.com', 'password123'],
    ['sara', 'sara28@yahoo.com', 'myp@ssw0rd'],
    ['Aditi', 'aditi.gupta@hotmail.com', 'myp@ssw0rd'],
    ['Amit', 'amit.singh@yahoo.com', 'welcome123'],
    ['Anaya', 'anaya.joshi@gmail.com', 'ilovecoding'],
    ['Aryan', 'aryan.verma@hotmail.com', 'myp@ssw0rd'],
    ['Aisha', 'aisha.khan@gmail.com', 'myp@ssw0rd'],
    ['Arjun', 'arjun.sharma@yahoo.com', '123456789'],
    ['Avani', 'avani.gupta@gmail.com', 'myp@ssw0rd'],
    ['Ayush', 'ayush.jain@hotmail.com', 'ilovecoding'],
    ['Bhavya', 'bhavya.singh@gmail.com', 'myp@ssw0rd'],
    ['Devansh', 'devansh.kumar@yahoo.com', 'password123'],
    ['Eesha', 'eesha.sharma@gmail.com', 'myp@ssw0rd'],
    ['Gauri', 'gauri.gupta@hotmail.com', 'welcome123'],
    ['Harshita', 'harshita.joshi@gmail.com', 'myp@ssw0rd'],
    ['Ishaan', 'ishaan.kumar@yahoo.com', 'ilovecoding'],
    ['Kavya', 'kavya.verma@gmail.com', 'myp@ssw0rd'],
    ['Priiii', 'pttrisha.sharma@hotmail.com', 'myp@ssw0rd'],
   
]
# Convert the testing data to a pandas DataFrame
X_test_df = pd.DataFrame(X_test, columns=['username', 'email', 'password'])

# Define the ColumnTransformer to perform one-hot encoding on selected columns
# Replace 'categorical_cols' with the actual list of column names that need one-hot encoding
categorical_cols = ['username', 'email' ,'password']
ct = ColumnTransformer(
    transformers=[('encoder', OneHotEncoder(), categorical_cols)],
    remainder='passthrough'
)

# Fit and transform the input features using ColumnTransformer
X_test_encoded = ct.fit_transform(X_test_df)

# Predict the outcomes using the trained decision tree
y_pred = clf.predict(X_test_encoded)

# Expected outcomes
expected_outcomes = [
    'Registration successful',
    'Registration successful',
    'Username already taken',  # Expected outcome for an unsuccessful registration (username already taken)
    'Email already registered',  # Expected outcome for an unsuccessful registration (email already registered)
    'Weak password',  # Expected outcome for an unsuccessful registration (weak password)
    'Unsuccessful registration',
    'Registration successful',
    'Unsuccessful registration',
    'Unsuccessful registration',
    'Unsuccessful registration',
    'Unsuccessful registration',
    'Registration successful',
    'Unsuccessful registration',
    'Registration successful',
    'Registration successful',
    'Unsuccessful registration',
    'Registration successful',
    'Registration successful',
    'Unsuccessful registration',
    'Registration successful',
    'Registration successful',  
]
# Compare the predicted outcomes with the expected outcomes
for i, outcome in enumerate(expected_outcomes):
    print(f"Test case {i + 1}:")
    print(f"Input: {X_test[i]}")
    print(f"Expected outcome: {outcome}")
    print(f"Predicted outcome: {y_pred[i]}")
    print("Result: ", "Pass" if y_pred[i] == outcome else "Fail")
    print("---------------------")
# Out:
# Test case 1:
# Input: ['deepti', 'deeptikannan@gmail.com', 'deeps']
# Expected outcome: Registration successful
# Predicted outcome: Unsuccessful registration
# Result:  Fail
# ---------------------
# Test case 2:
# Input: ['subhi', 'subbu@gmail.com', 'subbu']
# Expected outcome: Registration successful
# Predicted outcome: Registration successful
# Result:  Pass
# ---------------------
# Test case 3:
# Input: ['sarvesh', 'sarvu@gmail.com', 'darv']
# Expected outcome: Username already taken
# Predicted outcome: Username already taken
# Result:  Pass
# ---------------------
# Test case 4:
# Input: ['john', 'johnsmith@gmail.com', 'password123']
# Expected outcome: Email already registered
# Predicted outcome: Email already registered
# Result:  Pass
# ---------------------
# Test case 5:
# Input: ['sara', 'sara28@yahoo.com', 'myp@ssw0rd']
# Expected outcome: Weak password
# Predicted outcome: Weak password
# Result:  Pass
# ---------------------
# Test case 6:
# ...
